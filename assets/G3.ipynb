# %%
import pandas as pd
import numpy as np


df = pd.read_csv('G3D.csv')
df.head()
# Out:
#                           address   latitude  longitude
# 0              19th & E Street NW  38.896015 -77.049911
# 1  California St & Florida Ave NW  38.917761 -77.040620
# 2              Jefferson Memorial  38.881406 -77.036551
# 3        Army Navy Dr & S Nash St  38.861744 -77.068061
# 4                  16th & K St NW  38.902578 -77.055190

# %%
from pandas import Series, DataFrame
LL_ds=DataFrame(df)

DL=len(LL_ds)



DS_1=DataFrame(rd_1)

KL=len(DS_1)

SS_1=[]
SL_1=[]
SL_2=[]

for j in range(KL):
    #print(DDD.iloc[i]['address'])
    for i in range(DL):
        if str(DS_1.iloc[j]['Start station'])==str(LL_ds.iloc[i]['address']):
            print (format((int(j)/int(KL)),'0.5%'))
            SS_1.append(LL_ds.iloc[i]['address'])
            SL_1.append(LL_ds.iloc[i]['latitude'])
            SL_2.append(LL_ds.iloc[i]['longitude'])
            
print('finish')
# Out:
# 0.00000%
# 0.00057%
# 0.00114%
# 0.00172%
# 0.00229%
# 0.00286%
# 0.00343%
# 0.00400%
# 0.00458%
# 0.00515%
# 0.00572%
# 0.00629%
# 0.00686%
# 0.00744%
# 0.00801%
# 0.00858%
# 0.00915%
# 0.00973%
# 0.01030%
# 0.01087%
# 0.01144%
# 0.01201%
# 0.01259%
# 0.01316%
# 0.01373%
# 0.01430%
# 0.01487%
# 0.01545%
# 0.01602%
# 0.01659%
# 0.01716%
# 0.01773%
# 0.01831%
# 0.01888%
# 0.01945%
# 0.02002%
# 0.02059%
# 0.02117%
# 0.02174%
# 0.02231%
# 0.02288%
# 0.02345%
# 0.02403%
# 0.02460%
# 0.02517%
# 0.02574%
# 0.02632%
# 0.02689%
# 0.02746%
# 0.02803%
# 0.02860%
# 0.02918%
# 0.02975%
# 0.03032%
# 0.03089%
# 0.03146%
# 0.03204%
# 0.03261%
# 0.03318%
# 0.03375%
# 0.03432%
# 0.03490%
# 0.03547%
# 0.03604%
# 0.03661%
# 0.03718%
# 0.03776%
# 0.03833%
# 0.03890%
# 0.03947%
# 0.04004%
# 0.04062%
# 0.04119%
# 0.04176%
# 0.04233%
# 0.04291%
# 0.04348%
# 0.04405%
# 0.04462%
# 0.04519%
# 0.04577%
# 0.04634%
# 0.04691%
# 0.04748%
# 0.04805%
# 0.04863%
# 0.04920%
# 0.04977%
# 0.05034%
# 0.05091%
# ...

# %%
from pandas import Series, DataFrame


ES_1=[]
EL_1=[]
EL_2=[]

for q in range(KL):
    #print(DDD.iloc[i]['address'])
    for p in range(DL):
        if str(DS_1.iloc[q]['End station'])==str(LL_ds.iloc[p]['address']):
            print (format((int(q)/int(KL)),'0.5%'))
            ES_1.append(LL_ds.iloc[p]['address'])
            EL_1.append(LL_ds.iloc[p]['latitude'])
            EL_2.append(LL_ds.iloc[p]['longitude'])
            
print('finish')

# %%
#print(SL_1)

# %%
rd_1=pd.read_csv('DS_1.csv')
rd_1.head()
# Out:
#    Duration                 Start date                     End date  \
# 0    467192  Tuesday, January 31, 2017  Wednesday, February 1, 2017
# 1    397719  Tuesday, January 31, 2017  Wednesday, February 1, 2017
# 2    510162  Tuesday, January 31, 2017  Wednesday, February 1, 2017
# 3    222614  Tuesday, January 31, 2017    Tuesday, January 31, 2017
# 4    273541  Tuesday, January 31, 2017    Tuesday, January 31, 2017
#
#    Start station number                         Start station  \
# 0                 31200  Massachusetts Ave & Dupont Circle NW
# 1                 31111                        10th & U St NW
# 2                 31033             Barcroft Community Center
# 3                 31109                         7th & T St NW
# 4                 31007   Crystal City Metro / 18th & Bell St
#
#    End station number                End station Bike number Member Type
# 0               31125             15th & W St NW      W20700  Registered
# ...
